# %%
import os
import sys
root_path = os.path.abspath("..")  
if root_path not in sys.path:
    sys.path.insert(0, root_path)
os.chdir("..")

# %%
from data.loader import load_complete_dataset, analyze_dataset_quality, load_individual
dataset = load_complete_dataset()
dataset.head()
# Out:
#    device_id  accelerometer_x  accelerometer_y  accelerometer_z  gyroscope_x  \
# 0        1.0          -2.8243           9.1773           2.2388      -1.4334
# 1        1.0          -2.8002           9.1655           2.2507      -1.0434
# 2        1.0          -2.7881           9.1296           2.2634      -1.1208
# 3        1.0          -2.8240           9.1173           2.2522      -1.1517
# 4        1.0          -2.8240           9.1414           2.2517      -1.3618
#
#    gyroscope_y  gyroscope_z  magnetometer_x  magnetometer_y  magnetometer_z  \
# 0    -0.003309     -0.41384        -0.85484         0.50402         0.67483
# 1     0.230960     -0.12186        -0.85887         0.52610         0.67483
# 2     0.215210     -0.10277        -0.85081         0.52811         0.68374
# 3     0.143390      0.32778        -0.84879         0.50402         0.68820
# 4    -0.113230      0.65311        -0.86290         0.51807         0.68374
#
#    timestamp  actitivy_label  participant_id
# 0     1735.1             1.0              14
# 1     1754.6             1.0              14
# 2     1774.2             1.0              14
# 3     1793.7             1.0              14
# 4     1813.2             1.0              14

# %%
from config.constants import COLUMNS_ACCELEROMETER, COLUMNS_GYROSCOPE, COLUMNS_MAGNETOMETER
import numpy as np
def add_module_columns(dataset):
    """Adiciona colunas de módulo para cada sensor"""
    def calculate_module(columns, dataset, name):
        module = np.sqrt(np.sum(dataset[columns]**2, axis=1))
        dataset[name] = module
    calculate_module(COLUMNS_MAGNETOMETER, dataset, "magnetometer_module")
    calculate_module(COLUMNS_GYROSCOPE, dataset, "gyroscope_module")
    calculate_module(COLUMNS_ACCELEROMETER, dataset, "accelerometer_module")
    return dataset

dataset=add_module_columns(dataset)
dataset.head()
# Out:
#    device_id  accelerometer_x  accelerometer_y  accelerometer_z  gyroscope_x  \
# 0        1.0          -2.8243           9.1773           2.2388      -1.4334
# 1        1.0          -2.8002           9.1655           2.2507      -1.0434
# 2        1.0          -2.7881           9.1296           2.2634      -1.1208
# 3        1.0          -2.8240           9.1173           2.2522      -1.1517
# 4        1.0          -2.8240           9.1414           2.2517      -1.3618
#
#    gyroscope_y  gyroscope_z  magnetometer_x  magnetometer_y  magnetometer_z  \
# 0    -0.003309     -0.41384        -0.85484         0.50402         0.67483
# 1     0.230960     -0.12186        -0.85887         0.52610         0.67483
# 2     0.215210     -0.10277        -0.85081         0.52811         0.68374
# 3     0.143390      0.32778        -0.84879         0.50402         0.68820
# 4    -0.113230      0.65311        -0.86290         0.51807         0.68374
#
#    timestamp  actitivy_label  participant_id  magnetometer_module  \
# 0     1735.1             1.0              14             1.200076
# 1     1754.6             1.0              14             1.212367
# 2     1774.2             1.0              14             1.212550
# 3     1793.7             1.0              14             1.203370
# 4     1813.2             1.0              14             1.216755
#
#    gyroscope_module  accelerometer_module
# 0          1.491948              9.859601
# 1          1.075582              9.844448
# 2          1.145893              9.810509
# 3          1.205991              9.806760
# 4          1.514554              9.829055
